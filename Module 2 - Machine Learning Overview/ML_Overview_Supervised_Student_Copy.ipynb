# %% [markdown]
# # DOST AI Summer School 2017
#
# ## Copyright © 2017.  Rafael Cabredo and Maria Isabel Saludares

# %% [markdown]
# # Supervised learning

# %% [markdown]
# Welcome to an overview of machine learning!
#
# Remember the typical machine learning pipeline below?
#
# <img src="images/MLPipeline.png">
#
# Our task is to go through each step in the pipeline.

# %% [markdown]
# # 1. Get your data
#
# For this experiment, we will use a subset of the Breast Cancer Wisconsin dataset. This is found in the data folder: "data/breast-cancer-wisconsin.csv"
#
# The original data set can be downloaded from: [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Prognostic%29)
#
# The data has 10 features and 699 instances.  Feature information can be seen below:
# <pre>
#  No  Feature                      Domain
# ---------------------------------------------
#   0  Sample Code number            id no
#   1  Clump Thickness               1 - 10
#   2  Uniformity of Cell Size       1 - 10
#   3  Uniformity of Cell Shape      1 - 10
#   4  Marginal Adhesion             1 - 10
#   5  Single Epithelial Cell Size   1 - 10
#   6  Bare Nuclei                   1 - 10
#   7  Bland Chromatin               1 - 10
#   8  Normal Nucleoli               1 - 10
#   9  Mitoses                       1 - 10
#  10  Class:                        (benign or malignant)
# </pre>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

bcw_raw = pd.read_csv("data/breast-cancer-wisconsin.csv")
bcw_raw
# Out:
#           f0  f1  f2  f3  f4  f5  f6  f7  f8  f9      Class
# 0    1000025   5   1   1   1   2   1   3   1   1     benign
# 1    1002945   5   4   4   5   7  10   3   2   1     benign
# 2    1015425   3   1   1   1   2   2   3   1   1     benign
# 3    1016277   6   8   8   1   3   4   3   7   1     benign
# 4    1017023   4   1   1   3   2   1   3   1   1     benign
# 5    1017122   8  10  10   8   7  10   9   7   1  malignant
# 6    1018099   1   1   1   1   2  10   3   1   1     benign
# 7    1018561   2   1   2   1   2   1   3   1   1     benign
# 8    1033078   2   1   1   1   2   1   1   1   5     benign
# 9    1033078   4   2   1   1   2   1   2   1   1     benign
# 10   1035283   1   1   1   1   1   1   3   1   1     benign
# 11   1036172   2   1   1   1   2   1   2   1   1     benign
# 12   1041801   5   3   3   3   2   3   4   4   1  malignant
# 13   1043999   1   1   1   1   2   3   3   1   1     benign
# 14   1044572   8   7   5  10   7   9   5   5   4  malignant
# 15   1047630   7   4   6   4   6   1   4   3   1  malignant
# 16   1048672   4   1   1   1   2   1   2   1   1     benign
# 17   1049815   4   1   1   1   2   1   3   1   1     benign
# 18   1050670  10   7   7   6   4  10   4   1   2  malignant
# 19   1050718   6   1   1   1   2   1   3   1   1     benign
# 20   1054590   7   3   2  10   5  10   5   4   4  malignant
# 21   1054593  10   5   5   3   6   7   7  10   1  malignant
# 22   1056784   3   1   1   1   2   1   2   1   1     benign
# 23   1057013   8   4   5   1   2   ?   7   3   1  malignant
# 24   1059552   1   1   1   1   2   1   3   1   1     benign
# 25   1065726   5   2   3   4   2   7   3   6   1  malignant
# 26   1066373   3   2   1   1   1   1   2   1   1     benign
# 27   1066979   5   1   1   1   2   1   2   1   1     benign
# 28   1067444   2   1   1   1   2   1   2   1   1     benign
# 29   1070935   1   1   3   1   2   1   1   1   1     benign
# ..       ...  ..  ..  ..  ..  ..  ..  ..  ..  ..        ...
# 669  1350423   5  10  10   8   5   5   7  10   1  malignant
# 670  1352848   3  10   7   8   5   8   7   4   1  malignant
# 671  1353092   3   2   1   2   2   1   3   1   1     benign
# 672  1354840   2   1   1   1   2   1   3   1   1     benign
# 673  1354840   5   3   2   1   3   1   1   1   1     benign
# 674  1355260   1   1   1   1   2   1   2   1   1     benign
# 675  1365075   4   1   4   1   2   1   1   1   1     benign
# 676  1365328   1   1   2   1   2   1   2   1   1     benign
# 677  1368267   5   1   1   1   2   1   1   1   1     benign
# 678  1368273   1   1   1   1   2   1   1   1   1     benign
# 679  1368882   2   1   1   1   2   1   1   1   1     benign
# 680  1369821  10  10  10  10   5  10  10  10   7  malignant
# 681  1371026   5  10  10  10   4  10   5   6   3  malignant
# 682  1371920   5   1   1   1   2   1   3   2   1     benign
# 683   466906   1   1   1   1   2   1   1   1   1     benign
# 684   466906   1   1   1   1   2   1   1   1   1     benign
# 685   534555   1   1   1   1   2   1   1   1   1     benign
# 686   536708   1   1   1   1   2   1   1   1   1     benign
# 687   566346   3   1   1   1   2   1   2   3   1     benign
# 688   603148   4   1   1   1   2   1   1   1   1     benign
# 689   654546   1   1   1   1   2   1   1   1   8     benign
# 690   654546   1   1   1   3   2   1   1   1   1     benign
# 691   695091   5  10  10   5   4   5   4   4   1  malignant
# 692   714039   3   1   1   1   2   1   1   1   1     benign
# 693   763235   3   1   1   1   2   1   2   1   2     benign
# 694   776715   3   1   1   1   3   2   1   1   1     benign
# 695   841769   2   1   1   1   2   1   1   1   1     benign
# 696   888820   5  10  10   3   7   3   8  10   2  malignant
# 697   897471   4   8   6   4   3   4  10   6   1  malignant
# 698   897471   4   8   8   5   4   5  10   4   1  malignant
#
# [699 rows x 11 columns]

# %% [markdown]
# After loading your data, it is a good practice to see what your data looks like.
#
# Subtasks:
# 1. Determine how many samples are benign or malignant
# 2. Visualize the different features

# %%
#subtask 1


#subtask 2
ax = plt.subplot(111)

#f2: Uniformity of Cell Shape
f2_benign = bcw_raw[bcw_raw.Class=="benign"]["f2"]
f2_malignant = bcw_raw[bcw_raw.Class=="malignant"]["f2"]

ax.hist(f2_benign, width=0.2,color='b', label="benign")
ax.hist(f2_malignant, width=0.2,color='r', label="malignant")

plt.title("Uniformity of Cell Shape per class")
plt.legend()
plt.show()

# %%
# Subtask 2 (another data visualization)

# Histogram of all the features
x = bcw_raw.drop(bcw_raw.columns[[0, 10]], axis=1)
x = np.array(x, dtype=int)
feature_names = ["Clump Thickness", "Uniformity of Cell Size", "Uniformity of Cell Shape", 
                 "Marginal Adhesion", "Single Epithelial Cell Size", "Bare Nuclei",
                 "Bland Chromatin", "Normal Nucleoli", "Mitoses"]
df = pd.DataFrame(x, range(x.shape[0]), columns = feature_names)

bins = range(11)
for array in df.hist(bins=np.arange(10)-0.5, figsize=(20,15)):
    for subplot in array:
        subplot.set_xlim((-1,11))

# %% [markdown]
# # 2. Train your model

# %% [markdown]
# ## Logistic Regression
#
# This dataset is an example of the simplest form of classification problem -- a binary classification. We need our predictions to output either "benign" or "malignant". Thus, we need a <b>hypothesis</b> that can "convert" any numerical value to categorical values.
#
# We will use scikit-learn to implement this using linear_model.LogisticRegression()
#
# The training data will be split into test and training datasets using a 30:70 ratio.
#
# Additional reference:  http://scikit-learn.org/stable/modules/model_evaluation.html

# %%
from sklearn import linear_model, utils, metrics

#Prepare the data for training. We remove the label/Class.
target = "Class"
X = bcw_raw.drop(bcw_raw.columns[[0, 10]], axis=1)
X = np.array(X,dtype=int) #change everything to an integer (just in case)
y = bcw_raw[target]
X,y = utils.shuffle(X, y)

# Let's make the y values numerical (0: benign, 1: malignant) so we can plot it easily
y = pd.Categorical(y).codes

#Choose a subset for training

# split:  training (70%)   testing (30%)
X_train = X[:490]
y_train = y[:490]

X_test = X[491:]
y_test = y[491:]

#train the model
logres = linear_model.LogisticRegression()
logres.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# # 3. Test and validate your model

# %% [markdown]
# For evaluating our model, we want to use:
# 1. Accuracy
# 2. Precision
# 3. Recall
# 4. f1-score
#
# These can be obtained using the <b>metrics.classication_report</b> function.

# %%
y_pred = logres.predict(X_test)
print(metrics.classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98       139
#           1       0.98      0.93      0.96        69
#
# avg / total       0.97      0.97      0.97       208

# %% [markdown]
# Another method of evaluting this model is to use <b>cross validation</b>.

# %%
from sklearn import cross_validation

#Prepare the training and test sets again
X_train = X[:X.shape[0]]
y_train = y[:X.shape[0]]

#perform cross validation
y_pred = cross_validation.cross_val_predict(logres, X_train, y_train,cv=10)

#print the results
print(metrics.classification_report(y_train, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      0.98      0.97       458
#           1       0.96      0.94      0.95       241
#
# avg / total       0.97      0.97      0.97       699

# %%
# USE OTHER SUPERVISED METHODS:
